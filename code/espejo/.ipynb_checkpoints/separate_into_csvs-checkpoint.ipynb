# %% [markdown]
# # Separating Excel File into Convenient CSVs
# The five sheets in the excel file were not uniformly formatted. I had to switch and remove certain rows to be the column names of the csv files.

# %%
library(readxl)

# %%
data_path <- "../../data/Data_Sheet_3_Weighted Gene Co-expression Network Analysis of Endometriosis and Identification of Functional Modules Associated With Its Main Hallmarks.xlsx"
out_path  <- "../../data/csv/"

# %%
sheet_names <- excel_sheets(data_path)
csv_names <- paste0(sapply(sheet_names, function(x) paste0(strsplit(tolower(x), " ")[[1]], collapse="_")), ".csv")
csv_names
# Out:
# [1] "normal.csv"                 "minimal-mild.csv"
# [3] "mild-severe.csv"            "normal_vs_minimal-mild.csv"
# [5] "normal_vs_mild-severe.csv"

# %%
k <- 5
excel_file <- read_excel(data_path, sheet=k)

# %%
head(excel_file)
# Out:
#   ID          Gene.title                                          Gene.symbol
# 1 225420_at   glycerol-3-phosphate acyltransferase, mitochondrial GPAM
# 2 219717_at   DDB1 and CUL4 associated factor 16                  DCAF16
# 3 224730_at   DDB1 and CUL4 associated factor 7                   DCAF7
# 4 232064_at   fer (fps/fes related) tyrosine kinase               FER
# 5 226090_x_at RAB, member of RAS oncogene family-like 3           RABL3
# 6 1557167_at  HLA complex group 11 (non-protein coding)           HCG11
#   Gene.ID UniGene.title UniGene.symbol UniGene.ID
# 1 57678   NA            NA             NA
# 2 54876   NA            NA             NA
# 3 10238   NA            NA             NA
# 4 2241    NA            NA             NA
# 5 285282  NA            NA             NA
# 6 493812  NA            NA             NA
#   Nucleotide.Title
# 1 AV699379 GKC Homo sapiens cDNA clone GKCFVD06 3-, mRNA sequence
# 2 Homo sapiens DDB1 and CUL4 associated factor 16 (DCAF16), mRNA
# ...

# %%
names(excel_file) <- excel_file[1,]

# %%
head(excel_file)
# Out:
#   ID          Gene.title                                          Gene.symbol
# 1 225420_at   glycerol-3-phosphate acyltransferase, mitochondrial GPAM
# 2 219717_at   DDB1 and CUL4 associated factor 16                  DCAF16
# 3 224730_at   DDB1 and CUL4 associated factor 7                   DCAF7
# 4 232064_at   fer (fps/fes related) tyrosine kinase               FER
# 5 226090_x_at RAB, member of RAS oncogene family-like 3           RABL3
# 6 1557167_at  HLA complex group 11 (non-protein coding)           HCG11
#   Gene.ID UniGene.title UniGene.symbol UniGene.ID
# 1 57678   NA            NA             NA
# 2 54876   NA            NA             NA
# 3 10238   NA            NA             NA
# 4 2241    NA            NA             NA
# 5 285282  NA            NA             NA
# 6 493812  NA            NA             NA
#   Nucleotide.Title
# 1 AV699379 GKC Homo sapiens cDNA clone GKCFVD06 3-, mRNA sequence
# 2 Homo sapiens DDB1 and CUL4 associated factor 16 (DCAF16), mRNA
# ...

# %%
write.csv(excel_file, paste0(out_path, csv_names[k]))
