# %% [markdown]
# # Checking first 3 files for cleanliness

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.0.0     ✔ purrr   0.2.5
# ✔ tibble  1.4.2     ✔ dplyr   0.7.6
# ✔ tidyr   0.8.1     ✔ stringr 1.3.1
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
normal <- read_csv("../../data/csv/normal.csv")
# Out:
# Warning message:
# “Missing column names filled in: 'X5420' [5420]”Warning message:
# “Duplicated column names deduplicated: '2-Mar' => '2-Mar_1' [4886]”Parsed with column specification:
# cols(
#   .default = col_double(),
#   Samples = col_character()
# )
# See spec(...) for full column specifications.

# %%
names(normal)[4880:5000]
# Out:
#   [1] "MAPKAPK5.AS1" "MAPRE1"       "MAPRE3"       "MAPT"         "MAPT.AS1"
#   [6] "X2.Mar"       "X2.Mar.1"     "X5.Mar"       "X6.Mar"       "X7.Mar"
#  [11] "X8.Mar"       "X9.Mar"       "MARCKS"       "MARK1"        "MARK2"
#  [16] "MARK3"        "MARK4"        "MARVELD3"     "MASP1"        "MAST2"
#  [21] "MAST3"        "MAST4"        "MASTL"        "MAT2A"        "MAT2B"
#  [26] "MATK"         "MATR3"        "MAVS"         "MAX"          "MAZ"
#  [31] "MB"           "MB21D1"       "MBD2"         "MBD3"         "MBD4"
#  [36] "MBD5"         "MBD6"         "MBIP"         "MBLAC1"       "MBLAC2"
#  [41] "MBNL1"        "MBNL1.AS1"    "MBNL2"        "MBNL3"        "MBOAT1"
#  [46] "MBOAT2"       "MBOAT7"       "MBP"          "MBTD1"        "MBTPS1"
#  [51] "MBTPS2"       "MC1R"         "MCC"          "MCCC2"        "MCEE"
#  [56] "MCF2L"        "MCFD2"        "MCM10"        "MCM3"         "MCM3AP"
#  [61] "MCM3AP.AS1"   "MCM4"         "MCM6"         "MCM8"         "MCM9"
# ...
