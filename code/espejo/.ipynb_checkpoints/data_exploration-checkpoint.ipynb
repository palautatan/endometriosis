# %% [markdown]
# # Heatmaps

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12, 12)
# %matplotlib inline

# %%
normal = pd.read_csv("../../data/csv/normal.csv")
normal = normal.drop(normal.columns[0], axis=1)

# %%
normal.head()
# Out:
#       Samples      A1BG  A1BG-AS1    A4GALT      AA06      AAAS     AADAT  \
# 0  GSM1256800  3.615072  4.360865  4.714948  2.291045  6.405402  8.029920
# 1  GSM1256799  3.219856  4.443490  5.209183  2.407905  5.777939  7.673530
# 2  GSM1256798  3.605364  4.443490  4.880458  2.407905  6.632880  7.736981
# 3  GSM1256797  3.007682  4.648705  4.799252  2.407905  6.471050  6.106116
# 4  GSM1256796  3.561887  4.824626  4.799252  2.326374  6.268358  7.913295
#
#       AAED1     AAGAB      AAK1    ...        ZUFSP      ZW10    ZWILCH  \
# 0  8.169852  8.442643  9.035319    ...     6.988174  7.379993  9.491351
# 1  7.902539  8.633674  8.642446    ...     7.167312  7.262322  9.637907
# 2  7.789217  8.469552  9.165071    ...     7.055789  7.071272  9.827039
# 3  8.916237  7.678256  9.402699    ...     6.883567  7.003175  8.335426
# 4  7.655562  8.434126  8.995233    ...     7.146830  7.009203  9.306491
#
#        ZWINT      ZXDA      ZXDB      ZXDC     ZYG11B        ZYX      ZZZ3
# 0  10.291081  5.991668  6.895199  6.990095  10.008419  10.036205  8.631986
# 1  10.416580  5.736987  6.721002  7.070673  10.046513  10.095037  8.873484
# 2  10.637048  5.994896  6.694584  6.800409  10.262900   9.815911  8.797542
# 3   7.289707  5.439579  6.304896  6.940683   9.239314  10.709123  8.651204
# 4  10.017923  5.701701  6.675055  6.893976   9.949877  10.066109  8.680883
#
# [5 rows x 10129 columns]

# %%
normal.index = normal[normal.columns[0]]
normal = normal.drop(normal.columns[0], axis=1)

# %%
normal.head()
# Out:
#                 A1BG  A1BG-AS1    A4GALT      AA06      AAAS     AADAT  \
# Samples
# GSM1256800  3.615072  4.360865  4.714948  2.291045  6.405402  8.029920
# GSM1256799  3.219856  4.443490  5.209183  2.407905  5.777939  7.673530
# GSM1256798  3.605364  4.443490  4.880458  2.407905  6.632880  7.736981
# GSM1256797  3.007682  4.648705  4.799252  2.407905  6.471050  6.106116
# GSM1256796  3.561887  4.824626  4.799252  2.326374  6.268358  7.913295
#
#                AAED1     AAGAB      AAK1      AAMP    ...        ZUFSP  \
# Samples                                               ...
# GSM1256800  8.169852  8.442643  9.035319  8.803596    ...     6.988174
# GSM1256799  7.902539  8.633674  8.642446  8.161970    ...     7.167312
# GSM1256798  7.789217  8.469552  9.165071  8.815233    ...     7.055789
# GSM1256797  8.916237  7.678256  9.402699  9.183138    ...     6.883567
# GSM1256796  7.655562  8.434126  8.995233  8.935306    ...     7.146830
#
#                 ZW10    ZWILCH      ZWINT      ZXDA      ZXDB      ZXDC  \
# Samples
# GSM1256800  7.379993  9.491351  10.291081  5.991668  6.895199  6.990095
# GSM1256799  7.262322  9.637907  10.416580  5.736987  6.721002  7.070673
# GSM1256798  7.071272  9.827039  10.637048  5.994896  6.694584  6.800409
# GSM1256797  7.003175  8.335426   7.289707  5.439579  6.304896  6.940683
# GSM1256796  7.009203  9.306491  10.017923  5.701701  6.675055  6.893976
#
#                ZYG11B        ZYX      ZZZ3
# Samples
# GSM1256800  10.008419  10.036205  8.631986
# GSM1256799  10.046513  10.095037  8.873484
# GSM1256798  10.262900   9.815911  8.797542
# GSM1256797   9.239314  10.709123  8.651204
# GSM1256796   9.949877  10.066109  8.680883
#
# [5 rows x 10128 columns]

# %%
# normal_subset = normal[normal.columns[1:10]]
# normal_subset.head()
# Out:
#        A1BG  A1BG-AS1    A4GALT      AA06      AAAS     AADAT     AAED1  \
# 0  3.615072  4.360865  4.714948  2.291045  6.405402  8.029920  8.169852
# 1  3.219856  4.443490  5.209183  2.407905  5.777939  7.673530  7.902539
# 2  3.605364  4.443490  4.880458  2.407905  6.632880  7.736981  7.789217
# 3  3.007682  4.648705  4.799252  2.407905  6.471050  6.106116  8.916237
# 4  3.561887  4.824626  4.799252  2.326374  6.268358  7.913295  7.655562
#
#       AAGAB      AAK1
# 0  8.442643  9.035319
# 1  8.633674  8.642446
# 2  8.469552  9.165071
# 3  7.678256  9.402699
# 4  8.434126  8.995233

# %%
type(normal_subset)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.pcolor(normal_subset)
plt.yticks(np.arange(0.5, len(normal_subset.index), 1), normal_subset.index)
plt.xticks(np.arange(0.5, len(normal_subset.columns), 1), normal_subset.columns)
plt.show()

# %%
sns.heatmap(normal_subset, annot=True)

# %% [markdown]
# Exploring 4C.2. in http://press.endocrine.org/doi/suppl/10.1210/EN.2014-1490/suppl_file/en-14-1490.pdf
# and just for memory https://stackoverflow.com/questions/11285613/selecting-multiple-columns-in-a-pandas-dataframe

# %%
[x for x in list(normal.columns) if x.startswith("C")]
# Out:
# ['C10orf107',
#  'C10orf12',
#  'C10orf2',
#  'C10orf54',
#  'C10orf88',
#  'C11orf1',
#  'C11orf54',
#  'C11orf57',
#  'C11orf58',
#  'C11orf63',
#  'C11orf68',
#  'C11orf70',
#  'C11orf71',
#  'C11orf74',
#  'C11orf80',
#  'C11orf84',
#  'C11orf88',
#  'C11orf96',
#  'C11orf97',
#  'C12orf10',
#  'C12orf29',
#  'C12orf4',
#  'C12orf49',
#  'C12orf54',
#  'C12orf60',
#  'C12orf65',
#  'C12orf66',
#  'C12orf73',
#  'C12orf76',
#  'C14orf1',
#  'C14orf105',
#  'C14orf119',
#  'C14orf132',
#  'C14orf166',
#  'C14orf2',
#  'C14orf28',
#  'C14orf37',
#  'C14orf79',
#  'C14orf80',
#  'C15orf39',
#  'C15orf40',
#  'C15orf41',
#  'C15orf57',
#  'C15orf59',
#  'C15orf65',
#  'C16orf45',
#  'C16orf52',
#  'C16orf54',
#  'C16orf58',
#  'C16orf62',
#  'C16orf70',
#  'C16orf71',
#  'C16orf72',
#  'C16orf74',
#  'C16orf86',
#  'C16orf87',
#  'C17orf51',
#  'C17orf58',
#  'C17orf62',
#  'C17orf75',
#  'C17orf80',
#  'C17orf96',
#  'C17orf97',
#  'C18orf21',
#  'C18orf25',
#  'C18orf54',
#  'C18orf8',
#  'C19orf12',
#  'C19orf24',
#  'C19orf25',
#  'C19orf33',
#  'C19orf43',
#  'C19orf53',
#  'C19orf54',
#  'C19orf60',
#  'C19orf66',
#  'C19orf68',
#  'C19orf70',
#  'C19orf73',
#  'C19orf81',
#  'C1D',
#  'C1GALT1',
#  'C1GALT1C1',
#  'C1GALT1C1L',
#  'C1orf109',
#  'C1orf112',
#  'C1orf122',
#  'C1orf131',
#  'C1orf159',
#  'C1orf168',
#  'C1orf174',
#  'C1orf27',
#  'C1orf35',
#  'C1orf43',
#  'C1orf52',
#  'C1orf56',
#  'C1orf74',
#  'C1QA',
#  'C1QB',
#  'C1QBP',
#  'C1QC',
#  'C1QL1',
#  'C1QTNF1',
#  'C1QTNF7',
#  'C1RL',
#  'C1RL-AS1',
#  'C2',
#  'C20orf141',
#  'C20orf194',
#  'C20orf197',
#  'C20orf202',
#  'C20orf27',
#  'C21orf2',
#  'C21orf59',
#  'C21orf91',
#  'C2CD2',
#  'C2CD2L',
#  'C2CD3',
#  'C2CD4B',
#  'C2CD4C',
#  'C2CD5',
#  'C2orf15',
#  'C2orf27A',
#  'C2orf42',
#  'C2orf47',
#  'C2orf49',
#  'C2orf68',
#  'C2orf69',
#  'C2orf72',
#  'C2orf76',
#  'C2orf81',
#  'C2orf82',
#  'C2orf88',
#  'C3orf14',
#  'C3orf38',
#  'C3orf58',
#  'C3orf70',
#  'C4orf19',
#  'C4orf3',
#  'C4orf32',
#  'C4orf33',
#  'C4orf46',
#  'C4orf47',
#  'C5',
#  'C5orf15',
#  'C5orf22',
#  'C5orf24',
#  'C5orf30',
#  'C5orf34',
#  'C5orf42',
#  'C5orf46',
#  'C5orf49',
#  'C5orf51',
#  'C5orf56',
#  'C5orf63',
#  'C6orf1',
#  'C6orf106',
#  'C6orf118',
#  'C6orf120',
#  'C6orf132',
#  'C6orf136',
#  'C6orf15',
#  'C6orf203',
#  'C6orf62',
#  'C6orf89',
#  'C7orf26',
#  'C7orf43',
#  'C7orf50',
#  'C7orf57',
#  'C7orf61',
#  'C7orf73',
#  'C8orf34',
#  'C8orf37',
#  'C8orf48',
#  'C8orf58',
#  'C8orf59',
#  'C8orf76',
#  'C8orf82',
#  'C8orf88',
#  'C9orf135',
#  'C9orf142',
#  'C9orf16',
#  'C9orf172',
#  'C9orf3',
#  'C9orf40',
#  'C9orf64',
#  'C9orf69',
#  'C9orf72',
#  'C9orf78',
#  'C9orf85',
#  'CA12',
#  'CA4',
#  'CA5B',
#  'CA5BP1',
#  'CA8',
#  'CA9',
#  'CAAP1',
#  'CAB39',
#  'CAB39L',
#  'CABIN1',
#  'CABLES1',
#  'CABP1',
#  'CABP4',
#  'CACFD1',
#  'CACHD1',
#  'CACNA1A',
#  'CACNA1C',
#  'CACNA1D',
#  'CACNA1G',
#  'CACNA1H',
#  'CACNA2D1',
#  'CACNB3',
#  'CACNG4',
#  'CACNG6',
#  'CACNG8',
#  'CACTIN',
#  'CACUL1',
#  'CACYBP',
#  'CAD',
#  'CADM1',
#  'CADM4',
#  'CADPS',
#  'CALCOCO1',
#  'CALCOCO2',
#  'CALD1',
#  'CALHM2',
#  'CALM1',
#  'CALML4',
#  'CALR',
#  'CALU',
#  'CAMK2B',
#  'CAMK2D',
#  'CAMK2G',
#  'CAMK4',
#  'CAMKK2',
#  'CAMSAP1',
#  'CAMSAP2',
#  'CAMSAP3',
#  'CAMTA1',
#  'CAMTA2',
#  'CAND1',
#  'CANT1',
#  'CANX',
#  'CAP1',
#  'CAP2',
#  'CAPN1',
#  'CAPN10',
#  'CAPN15',
#  'CAPN2',
#  'CAPN5',
#  'CAPN7',
#  'CAPNS1',
#  'CAPRIN1',
#  'CAPRIN2',
#  'CAPS',
#  'CAPS2',
#  'CAPSL',
#  'CAPZA1',
#  'CAPZA2',
#  'CAPZB',
#  'CARD11',
#  'CARD14',
#  'CARD16',
#  'CARD19',
#  'CARD6',
#  'CARD8',
#  'CARF',
#  'CARMIL2',
#  'CARMIL3',
#  'CARMN',
#  'CARNMT1',
#  'CARS',
#  'CARS2',
#  'CASC1',
#  'CASC15',
#  'CASC4',
#  'CASD1',
#  'CASK',
#  'CASKIN1',
#  'CASKIN2',
#  'CASP1',
#  'CASP10',
#  'CASP2',
#  'CASP3',
#  'CASP4',
#  'CASP6',
#  'CASP7',
#  'CASP8',
#  'CASP8AP2',
#  'CASP9',
#  'CASR',
#  'CAST',
#  'CASZ1',
#  'CAT',
#  'CAV1',
#  'CAV2',
#  'CBFA2T2',
#  'CBFB',
#  'CBL',
#  'CBLB',
#  'CBLL1',
#  'CBLN2',
#  'CBLN3',
#  'CBR3-AS1',
#  'CBR4',
#  'CBS',
#  'CBX1',
#  'CBX2',
#  'CBX3',
#  'CBX4',
#  'CBX5',
#  'CBX6',
#  'CBX7',
#  'CBX8',
#  'CBY1',
#  'CC2D1A',
#  'CC2D2A',
#  'CCAR1',
#  'CCAR2',
#  'CCBE1',
#  'CCDC106',
#  'CCDC112',
#  'CCDC113',
#  'CCDC117',
#  'CCDC120',
#  'CCDC121',
#  'CCDC124',
#  'CCDC125',
#  'CCDC126',
#  'CCDC130',
#  'CCDC134',
#  'CCDC138',
#  'CCDC14',
#  'CCDC146',
#  'CCDC148',
#  'CCDC150',
#  'CCDC151',
#  'CCDC152',
#  'CCDC157',
#  'CCDC159',
#  'CCDC169',
#  'CCDC170',
#  'CCDC171',
#  'CCDC174',
#  'CCDC18',
#  'CCDC181',
#  'CCDC184',
#  'CCDC186',
#  'CCDC189',
#  'CCDC191',
#  'CCDC22',
#  'CCDC24',
#  'CCDC25',
#  'CCDC28A',
#  'CCDC30',
#  'CCDC33',
#  'CCDC34',
#  'CCDC40',
#  'CCDC43',
#  'CCDC47',
#  'CCDC50',
#  'CCDC53',
#  'CCDC57',
#  'CCDC58',
#  'CCDC59',
#  'CCDC6',
#  'CCDC60',
#  'CCDC61',
#  'CCDC65',
#  'CCDC66',
#  'CCDC71',
#  'CCDC71L',
#  'CCDC77',
#  'CCDC8',
#  'CCDC81',
#  'CCDC82',
#  'CCDC85B',
#  'CCDC86',
#  'CCDC88A',
#  'CCDC88B',
#  'CCDC88C',
#  'CCDC89',
#  'CCDC9',
#  'CCDC90B',
#  'CCDC91',
#  'CCDC92',
#  'CCDC93',
#  'CCDC94',
#  'CCDC97',
#  'CCHCR1',
#  'CCL17',
#  'CCL19',
#  'CCL2',
#  'CCL21',
#  'CCL28',
#  'CCL4',
#  'CCM2',
#  'CCNA1',
#  'CCNA2',
#  'CCNB1',
#  'CCNB1IP1',
#  'CCNB2',
#  'CCNC',
#  'CCND1',
#  'CCND2',
#  'CCND3',
#  'CCNDBP1',
#  'CCNE2',
#  'CCNG1',
#  'CCNG2',
#  'CCNH',
#  'CCNI',
#  'CCNJ',
#  'CCNJL',
#  'CCNL2',
#  'CCNT1',
#  'CCNT2',
#  'CCNY',
#  'CCNYL1',
#  'CCP110',
#  'CCPG1',
#  'CCR10',
#  'CCSAP',
#  'CCSER2',
#  'CCT2',
#  'CCT3',
#  'CCT4',
#  'CCT5',
#  'CCT6A',
#  'CCT6B',
#  'CCT7',
#  'CCT8',
#  'CD109',
#  'CD14',
#  'CD151',
#  'CD164',
#  'CD1D',
#  'CD200',
#  'CD24',
#  'CD248',
#  'CD27',
#  'CD276',
#  'CD2AP',
#  'CD2BP2',
#  'CD37',
#  'CD3E',
#  'CD4',
#  'CD40',
#  'CD44',
#  'CD46',
#  'CD47',
#  'CD48',
#  'CD52',
#  'CD58',
#  'CD59',
#  'CD6',
#  'CD63',
#  'CD7',
#  'CD70',
#  'CD74',
#  'CD79A',
#  'CD79B',
#  'CD81',
#  'CD82',
#  'CD8B',
#  'CD9',
#  'CD93',
#  'CD99',
#  'CDA',
#  'CDADC1',
#  'CDC123',
#  'CDC14A',
#  'CDC14B',
#  'CDC16',
#  'CDC20B',
#  'CDC23',
#  'CDC25C',
#  'CDC26',
#  'CDC27',
#  'CDC34',
#  'CDC37L1',
#  'CDC40',
#  'CDC42',
#  'CDC42-IT1',
#  'CDC42BPA',
#  'CDC42EP1',
#  'CDC42EP2',
#  'CDC42EP3',
#  'CDC42EP4',
#  'CDC42EP5',
#  'CDC42SE1',
#  'CDC42SE2',
#  'CDC45',
#  'CDC5L',
#  'CDC6',
#  'CDC7',
#  'CDC73',
#  'CDCA2',
#  'CDCA7',
#  'CDCA7L',
#  'CDH1',
#  'CDH11',
#  'CDH2',
#  'CDH24',
#  'CDH4',
#  'CDHR2',
#  'CDIP1',
#  'CDIPT',
#  'CDK1',
#  'CDK10',
#  'CDK12',
#  'CDK13',
#  'CDK14',
#  'CDK16',
#  'CDK17',
#  'CDK18',
#  'CDK19',
#  'CDK2AP1',
#  'CDK2AP2',
#  'CDK5RAP2',
#  'CDK5RAP3',
#  'CDK6',
#  'CDK7',
#  'CDK8',
#  'CDK9',
#  'CDKAL1',
#  'CDKL1',
#  'CDKL3',
#  'CDKN1A',
#  'CDKN1B',
#  'CDKN1C',
#  'CDKN2A',
#  'CDKN2AIP',
#  'CDKN2D',
#  'CDKN3',
#  'CDO1',
#  'CDPF1',
#  'CDR2L',
#  'CDRT15',
#  'CDS1',
#  'CDS2',
#  'CDV3',
#  'CDX1',
#  'CDYL',
#  'CEACAM1',
#  'CEACAM3',
#  'CEBPA',
#  'CEBPA-AS1',
#  'CEBPB',
#  'CEBPD',
#  'CEBPE',
#  'CEBPG',
#  'CEBPZ',
#  'CEBPZOS',
#  'CECR2',
#  'CELF1',
#  'CELF2',
#  'CELF3',
#  'CELSR3',
#  'CEMP1',
#  'CEND1',
#  'CENPB',
#  'CENPBD1',
#  'CENPBD1P1',
#  'CENPC',
#  'CENPE',
#  'CENPF',
#  'CENPI',
#  'CENPJ',
#  'CENPK',
#  'CENPL',
#  'CENPN',
#  'CENPO',
#  'CENPQ',
#  'CENPT',
#  'CENPU',
#  'CENPW',
#  'CEP104',
#  'CEP112',
#  'CEP120',
#  'CEP126',
#  'CEP128',
#  'CEP135',
#  'CEP152',
#  'CEP162',
#  'CEP164',
#  'CEP170B',
#  'CEP19',
#  'CEP192',
#  'CEP290',
#  'CEP295',
#  'CEP350',
#  'CEP41',
#  'CEP44',
#  'CEP55',
#  'CEP57',
#  'CEP57L1',
#  'CEP63',
#  'CEP68',
#  'CEP70',
#  'CEP76',
#  'CEP78',
#  'CEP83',
#  'CEP85',
#  'CEP89',
#  'CEP95',
#  'CEP97',
#  'CEPT1',
#  'CERCAM',
#  'CERK',
#  'CERS2',
#  'CERS4',
#  'CERS6',
#  'CES3',
#  'CETN2',
#  'CETN3',
#  'CETP',
#  'CFAP206',
#  'CFAP36',
#  'CFAP43',
#  'CFAP44',
#  'CFAP46',
#  'CFAP53',
#  'CFAP69',
#  'CFAP70',
#  'CFAP97',
#  'CFB',
#  'CFD',
#  'CFDP1',
#  'CFH',
#  'CFI',
#  'CFL1',
#  'CFL2',
#  'CFLAR',
#  'CFP',
#  'CGGBP1',
#  'CGNL1',
#  'CGRRF1',
#  'CHAC1',
#  'CHAC2',
#  'CHADL',
#  'CHAF1B',
#  'CHCHD10',
#  'CHCHD3',
#  'CHCHD5',
#  'CHCHD7',
#  'CHD1',
#  'CHD1L',
#  'CHD2',
#  'CHD4',
#  'CHD6',
#  'CHD7',
#  'CHD8',
#  'CHD9',
#  'CHEK1',
#  'CHEK2',
#  'CHERP',
#  'CHIC1',
#  'CHID1',
#  'CHKB',
#  'CHKB-AS1',
#  'CHM',
#  'CHML',
#  'CHMP1A',
#  'CHMP1B',
#  'CHMP2B',
#  'CHMP4C',
#  'CHMP5',
#  'CHMP6',
#  'CHN1',
#  'CHORDC1',
#  'CHPF',
#  'CHPF2',
#  'CHPT1',
#  'CHRD',
#  'CHRNA2',
#  'CHRNB2',
#  'CHST1',
#  'CHST11',
#  'CHST12',
#  'CHST15',
#  'CHST7',
#  'CHST8',
#  'CHSY1',
#  'CHSY3',
#  'CHTF8',
#  'CHTOP',
#  'CHUK',
#  'CHURC1',
#  'CIAO1',
#  'CIAPIN1',
#  'CIB2',
#  'CIC',
#  'CIDEB',
#  'CIDEC',
#  'CILP2',
#  'CIPC',
#  'CIR1',
#  'CIRBP',
#  'CIRBP-AS1',
#  'CISD2',
#  'CISD3',
#  'CISH',
#  'CITED2',
#  'CITED4',
#  'CIZ1',
#  'CKAP2',
#  'CKAP2L',
#  'CKAP4',
#  'CKAP5',
#  'CKM',
#  'CKMT2-AS1',
#  'CKS1B',
#  'CLASP2',
#  'CLASRP',
#  'CLCC1',
#  'CLCF1',
#  'CLCN1',
#  'CLCN2',
#  'CLCN3',
#  'CLCN4',
#  'CLCN5',
#  'CLCN7',
#  'CLCNKB',
#  'CLDN12',
#  'CLDN14',
#  'CLDN3',
#  'CLDN4',
#  'CLDN5',
#  'CLDN7',
#  'CLDND1',
#  'CLEC2D',
#  'CLEC4A',
#  'CLECL1',
#  'CLGN',
#  'CLHC1',
#  'CLIC1',
#  'CLIC2',
#  'CLIC4',
#  'CLIC5',
#  'CLINT1',
#  'CLIP1',
#  'CLIP3',
#  'CLIP4',
#  'CLK1',
#  'CLK4',
#  'CLMN',
#  'CLMP',
#  'CLN3',
#  'CLN5',
#  'CLN6',
#  'CLN8',
#  'CLNS1A',
#  'CLOCK',
#  'CLP1',
#  'CLPB',
#  'CLPP',
#  'CLPS',
#  'CLPTM1',
#  'CLPTM1L',
#  'CLPX',
#  'CLSPN',
#  'CLSTN1',
#  'CLSTN2',
#  'CLSTN3',
#  'CLTB',
#  'CLTC',
#  'CLTCL1',
#  'CLUAP1',
#  'CLUH',
#  'CLUHP3',
#  'CLYBL',
#  'CMAS',
#  'CMBL',
#  'CMC2',
#  'CMIP',
#  'CMPK1',
#  'CMPK2',
#  'CMSS1',
#  'CMTM1',
#  'CMTM4',
#  'CMTM6',
#  'CMTM7',
#  'CMTR2',
#  'CNBP',
#  'CNEP1R1',
#  'CNFN',
#  'CNGB1',
#  'CNIH1',
#  'CNIH4',
#  'CNKSR1',
#  'CNKSR2',
#  'CNKSR3',
#  'CNN1',
#  'CNN2',
#  'CNN3',
#  'CNNM1',
#  'CNNM2',
#  'CNNM3',
#  'CNOT1',
#  'CNOT10',
#  'CNOT11',
#  'CNOT2',
#  'CNOT3',
#  'CNOT4',
#  'CNOT6',
#  'CNOT6L',
#  'CNOT7',
#  'CNOT8',
#  'CNOT9',
#  'CNP',
#  'CNPPD1',
#  'CNPY3',
#  'CNPY4',
#  'CNST',
#  'CNTFR',
#  'CNTLN',
#  'CNTN1',
#  'CNTN3',
#  'CNTNAP1',
#  'CNTRL',
#  'CNTROB',
#  'COA1',
#  'COA5',
#  'COA6',
#  'COA7',
#  'COASY',
#  'COBL',
#  'COCH',
#  'COG1',
#  'COG2',
#  'COG3',
#  'COG5',
#  'COG6',
#  'COG8',
#  'COIL',
#  'COL11A1',
#  'COL11A2',
#  'COL12A1',
#  'COL14A1',
#  'COL18A1',
#  'COL1A1',
#  'COL21A1',
#  'COL26A1',
#  'COL3A1',
#  'COL4A2',
#  'COL4A3BP',
#  'COL5A2',
#  'COL5A3',
#  'COL6A1',
#  'COL6A2',
#  'COLCA1',
#  'COLEC12',
#  'COLGALT1',
#  'COLQ',
#  'COMMD10',
#  'COMMD2',
#  'COMMD3',
#  'COMMD4',
#  'COMMD8',
#  'COMT',
#  'COMTD1',
#  'COPA',
#  'COPB1',
#  'COPB2',
#  'COPE',
#  'COPG2',
#  'COPS2',
#  'COPS3',
#  'COPS4',
#  'COPS5',
#  'COPS8',
#  'COPZ2',
#  'COQ10B',
#  'COQ2',
#  'COQ3',
#  'COQ4',
#  'COQ5',
#  'COQ7',
#  'COQ8A',
#  'COQ8B',
#  'CORO1A',
#  'CORO1B',
#  'CORO1C',
#  'CORO2A',
#  'CORO7',
#  'COX1',
#  'COX11',
#  'COX15',
#  'COX16',
#  'COX18',
#  'COX19',
#  'COX2',
#  'COX20',
#  'COX4I1',
#  'COX4I2',
#  'COX5B',
#  'COX6A2',
#  'COX6C',
#  'COX7B',
#  'COX7C',
#  'CPAMD8',
#  'CPD',
#  'CPE',
#  'CPEB3',
#  'CPEB4',
#  'CPLX1',
#  'CPM',
#  'CPNE1',
#  'CPNE2',
#  'CPNE3',
#  'CPNE5',
#  'CPNE7',
#  'CPNE9',
#  'CPOX',
#  'CPPED1',
#  'CPQ',
#  'CPSF2',
#  'CPSF3',
#  'CPSF3L',
#  'CPSF4',
#  'CPSF6',
#  'CPSF7',
#  'CPTP',
#  'CRACR2A',
#  'CRACR2B',
#  'CRAMP1',
#  'CRAT',
#  'CRB3',
#  'CRBN',
#  'CREB1',
#  'CREB3L1',
#  'CREB3L2',
#  'CREBL2',
#  'CREBRF',
#  'CREBZF',
#  'CREG1',
#  'CRELD2',
#  'CREM',
#  'CRH',
#  'CRIM1',
#  'CRIP2',
#  'CRIPT',
#  'CRISPLD1',
#  'CRK',
#  'CRKL',
#  'CRLF1',
#  'CRLF3',
#  'CRLS1',
#  'CRNKL1',
#  'CROCC',
#  'CROT',
#  'CRTAC1',
#  'CRTAP',
#  'CRTC1',
#  'CRTC2',
#  'CRTC3',
#  'CRY1',
#  'CRY2',
#  'CRYAB',
#  'CRYBG3',
#  'CRYZ',
#  'CRYZL1',
#  'CS',
#  'CSDC2',
#  'CSDE1',
#  'CSE1L',
#  'CSF1',
#  'CSF1R',
#  'CSF2',
#  'CSF3R',
#  'CSGALNACT2',
#  'CSK',
#  'CSMD2',
#  'CSNK1A1',
#  'CSNK1D',
#  'CSNK1E',
#  'CSNK1G1',
#  'CSNK1G2',
#  'CSNK1G3',
#  'CSNK2A1',
#  'CSNK2A2',
#  'CSNK2B',
#  'CSPG4',
#  'CSPP1',
#  'CSRNP1',
#  'CSRNP2',
#  'CSRNP3',
#  'CSRP1',
#  'CST1',
#  'CST2',
#  'CST3',
#  'CST4',
#  'CST7',
#  'CSTB',
#  'CSTF1',
#  'CSTF2',
#  'CSTF2T',
#  'CSTF3',
#  'CTAG2',
#  ...]

# %%
core_genes = normal[["CDC42SE2", "WBSCR27", "NT5E"]]

# %%
sns.heatmap(core_genes, annot=True)

# %%
ms = pd.read_csv("../../data/csv/mild-severe.csv")
ms = ms.drop(ms.columns[0], axis=1)

# %%
core_genes_2 = ms[["CDC42SE2", "WBSCR27", "NT5E"]]
sns.heatmap(core_genes_2, annot=True)

# %% [markdown]
# # What size of data are we working with?

# %%
normal.shape
# Out:
# (34, 10128)

# %%
ms.shape
# Out:
# (46, 10129)

# %%
bool_test = list(ms.columns == normal.columns)
[i for i, x in enumerate(bool_test) if x==False]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-7d2de4b551fd> in <module>()
# ----> 1 bool_test = list(ms.columns == normal.columns)
#       2 [i for i, x in enumerate(bool_test) if x==False]
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in cmp_method(self, other)
#      91         if isinstance(other, (np.ndarray, Index, ABCSeries)):
#      92             if other.ndim > 0 and len(self) != len(other):
# ---> 93                 raise ValueError('Lengths must match to compare')
#      94
#      95         # we may need to directly compare underlying
#
# ValueError: Lengths must match to compare

# %% [markdown]
# ## What is the NA?
# In the ms sheet, there is two columns corresponding with gene 42796.

# %%
list(set(normal.columns) - set(ms.columns))
# Out:
# []

# %%
list(set(ms.columns) - set(normal.columns))
# Out:
# ['NA.1']

# %%
normal.columns[10126]
# Out:
# 'ZYX'

# %%
ms.columns[10127]
# Out:
# 'ZYX'

# %%
ms[[ms.columns[5419]]].head()
# Out:
#         NA.1
# 0  15.353043
# 1  15.243017
# 2  15.276093
# 3  15.292509
# 4  15.234722

# %%
ms.columns
# Out:
# Index([u'NA', u'A1BG', u'A1BG-AS1', u'A4GALT', u'AA06', u'AAAS', u'AADAT',
#        u'AAED1', u'AAGAB', u'AAK1',
#        ...
#        u'ZUFSP', u'ZW10', u'ZWILCH', u'ZWINT', u'ZXDA', u'ZXDB', u'ZXDC',
#        u'ZYG11B', u'ZYX', u'ZZZ3'],
#       dtype='object', length=10129)
