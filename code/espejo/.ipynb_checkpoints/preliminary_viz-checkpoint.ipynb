# %% [markdown]
# # Preliminary Viz
# I'll do some visualization to see what we're working with.

# %%
library(tidyverse)
library(reshape2)
library(plyr)
library(ggplot2)
library(scales)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.0.0     ✔ purrr   0.2.5
# ✔ tibble  1.4.2     ✔ dplyr   0.7.6
# ✔ tidyr   0.8.1     ✔ stringr 1.3.1
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘reshape2’
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
# ------------------------------------------------------------------------------
# You have loaded plyr after dplyr - this is likely to cause problems.
# If you need functions from both plyr and dplyr, please load plyr first, then dplyr:
# library(plyr); library(dplyr)
# ------------------------------------------------------------------------------
#
# Attaching package: ‘plyr’
#
# The following objects are masked from ‘package:dplyr’:
#
# ...

# %% [markdown]
# # Read data

# %%
this_sub <- read_csv("../../data/genbank/clean-csv/small_subset.csv")[,-1]
head(this_sub)
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   .default = col_double(),
#   X1 = col_integer(),
#   sample = col_character(),
#   tissue = col_character(),
#   endometriosis = col_character(),
#   severity = col_character()
# )
# See spec(...) for full column specifications.
#   sample     tissue                             endometriosis severity
# 1 GSM1256653 Early Secretory Endometrial tissue Endometriosis Moderate/Severe
# 2 GSM1256654 Early Secretory Endometrial tissue Endometriosis Moderate/Severe
# 3 GSM1256655 Proliferative Endometrial tissue   Endometriosis Moderate/Severe
# 4 GSM1256656 Mid-Secretory Endometrial tissue   Endometriosis Moderate/Severe
# 5 GSM1256657 Early Secretory Endometrial tissue Endometriosis Moderate/Severe
# 6 GSM1256658 Mid-Secretory Endometrial tissue   Endometriosis Moderate/Severe
#   229809_at 224476_s_at 215863_at 212522_at 226667_x_at 239457_at ⋯ 204620_s_at
# ...

# %% [markdown]
# # Distribution of Sample

# %%
ggplot(this_sub, aes(x=endometriosis)) +
    geom_histogram(stat="count", aes(fill=severity)) +
    ggtitle("Subject Distribution")
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth, bins, pad”
# plot without title

# %% [markdown]
# # Heatmap of Series
# Here's a heatmap of the random subset I chose.

# %%
this_melt <- melt(this_sub[,c(1,5:ncol(this_sub))])
# Out:
# Using sample as id variables

# %%
this_melt <- ddply(this_melt, .(variable), transform, rescale = rescale(value))

# %% [markdown]
# I don't know what `rescale` does in this case.

# %%
head(this_melt)
# Out:
#   sample     variable  value    rescale
# 1 GSM1256653 229809_at 2.556258 0.09053283
# 2 GSM1256654 229809_at 2.442307 0.05831360
# 3 GSM1256655 229809_at 2.623213 0.10946411
# 4 GSM1256656 229809_at 2.678427 0.12507567
# 5 GSM1256657 229809_at 2.255125 0.00538858
# 6 GSM1256658 229809_at 2.489543 0.07166941

# %%
ggplot(this_melt, aes(variable, sample)) +
    geom_tile(aes(fill = value), colour = "white") +
    scale_fill_gradient(low = "white", high = "steelblue") +
    theme(axis.text.x = element_text(angle = 90, hjust = 1))
# Out:
# plot without title

# %%
ggplot(this_melt, aes(variable, sample)) +
    geom_tile(aes(fill = rescale), colour = "white") +
    scale_fill_gradient(low = "white", high = "midnightblue") +
    xlab("probe") +
    theme(text = element_text(size=4),
          axis.text.x = element_text(angle = 90, hjust = 1))
# Out:
# plot without title
